# %% [markdown]
# <a href="https://colab.research.google.com/github/FDS116/MIQ/blob/main/Nanopart%C3%ADculas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import bokeh as bk

# %% [markdown]
# #oDIDA

# %%
datos=pd.read_excel("/content/drive/MyDrive/NPs/nanos_python.xlsx",sheet_name="oDIDA")
datos.head()
# Out:
#    Longitud de onda (nm)   8 min  13 min  30 min  1 hora  4 días   14 días  \
# 0                    200  0.2951  0.3009  0.2183  0.2551   0.2075   0.2733
# 1                    205  0.1994  0.1793  0.2427  0.2539   0.2565   0.3080
# 2                    210  0.2208  0.2477  0.2054  0.2174   0.2320   0.3142
# 3                    215  0.2568  0.2951  0.2271  0.2395   0.2230   0.3574
# 4                    220  0.2375  0.2614  0.2944  0.2730   0.2873   0.3197
#
#    27 días  35 días  40 días  47 días  55 días  61 días  75 días  105 días
# 0   0.2733   0.2929   0.3270   0.2831   0.2937   0.2661   0.3870     3.5617
# 1   0.3080   0.3063   0.2832   0.2556   0.3236   0.2961   0.4134     3.6253
# 2   0.3142   0.1456   0.2174   0.2706   0.3353   0.3325   0.4406     3.6829
# 3   0.3574   0.2766   0.2673   0.2327   0.3744   0.3586   0.4320     3.7371
# 4   0.3197   0.2566   0.2235   0.2740   0.3227   0.2850   0.4397     3.8151

# %%
wavelenght=datos.iloc[40:121,0]
absorbance_1=datos.iloc[40:121,1]
absorbance_2=datos.iloc[40:121,2]
absorbance_3=datos.iloc[40:121,3]
absorbance_4=datos.iloc[40:121,4]
absorbance_5=datos.iloc[40:121,5]
absorbance_6=datos.iloc[40:121,6]
absorbance_7=datos.iloc[40:121,7]
absorbance_8=datos.iloc[40:121,8]
absorbance_9=datos.iloc[40:121,9]
absorbance_10=datos.iloc[40:121,10]
absorbance_11=datos.iloc[40:121,11]
absorbance_12=datos.iloc[40:121,12]
absorbance_13=datos.iloc[40:121,13]
absorbance_14=datos.iloc[40:121,14]

# %%
plt.style.use("seaborn-v0_8")
plt.plot(wavelenght,absorbance_1,label="8 min")
plt.plot(wavelenght,absorbance_2,label="13 min")
plt.plot(wavelenght,absorbance_3,label="30 min")
plt.plot(wavelenght,absorbance_5,label="4 días")
plt.plot(wavelenght,absorbance_6,label="14 días")
plt.plot(wavelenght,absorbance_8,label="35 días")
plt.plot(wavelenght,absorbance_9,label="40 días")
plt.plot(wavelenght,absorbance_11,label="55 días")
plt.plot(wavelenght,absorbance_12,label="105 días")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("absorbancia (a.u.)")
plt.legend(loc="best", frameon=False)
plt.show()

# %% [markdown]
# #34DITA

# %%
datos=pd.read_excel("/content/drive/MyDrive/NPs/nanos_python.xlsx",sheet_name="34DITA")
datos.head()
# Out:
#    Longitud de onda (nm)   5 min  12 min  30 min  2 días  7 días  14 días  \
# 0                    200  0.0784  0.0705  0.1483  0.1073  0.1429   0.1804
# 1                    205  0.0733  0.0295  0.1790  0.1857  0.1641   0.2562
# 2                    210  0.0657  0.0850  0.1658  0.2462  0.1726   0.2544
# 3                    215  0.0453  0.0592  0.1884  0.1886  0.1331   0.2868
# 4                    220  0.1006  0.0941  0.2290  0.1859  0.2009   0.3103
#
#    22 días  28 días  70 días  100 días  130 días
# 0   0.2166   0.2615   3.3670    3.3825    3.3825
# 1   0.2531   0.2148   3.4498    3.4362    3.4362
# 2   0.2021   0.2720   3.5076    3.4661    3.4661
# 3   0.2199   0.2353   3.5158    3.4981    3.4981
# 4   0.2740   0.2788   3.5645    3.5771    3.5771

# %%
wavelenght=datos.iloc[50:121,0]
absorbance_1=datos.iloc[50:121,1]
absorbance_2=datos.iloc[50:121,2]
absorbance_3=datos.iloc[50:121,3]
absorbance_4=datos.iloc[50:121,4]
absorbance_5=datos.iloc[50:121,5]
absorbance_6=datos.iloc[50:121,6]
absorbance_7=datos.iloc[50:121,7]
absorbance_8=datos.iloc[50:121,8]
absorbance_9=datos.iloc[50:121,9]
absorbance_10=datos.iloc[50:121,10]
absorbance_11=datos.iloc[50:121,11]

# %%
plt.style.use("seaborn-v0_8")
plt.plot(wavelenght,absorbance_1,label="5 min")
plt.plot(wavelenght,absorbance_2,label="12 min")
plt.plot(wavelenght,absorbance_3,label="30 min")
plt.plot(wavelenght,absorbance_4,label="2 días")
plt.plot(wavelenght,absorbance_5,label="7 días")
plt.plot(wavelenght,absorbance_6,label="14 días")
plt.plot(wavelenght,absorbance_7,label="22 días")
plt.plot(wavelenght,absorbance_8,label="28 días")
plt.plot(wavelenght,absorbance_9,label="48 días")
plt.plot(wavelenght,absorbance_10,label="90 días")
plt.plot(wavelenght,absorbance_11,label="120 días")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("absorbancia (a.u.)")
plt.legend(loc="best", frameon=False)
plt.show()

# %% [markdown]
# #35DITA

# %%
datos=pd.read_excel("/content/drive/MyDrive/NPs/nanos_python.xlsx",sheet_name="35DITA")
datos.head()
# Out:
#    Longitud de onda (nm)   5 min  12 min  35 min  2 días  7 días  14 días  \
# 0                    200  0.2074  0.2427  0.1584  0.2228  0.4255   0.2983
# 1                    205  0.2549  0.2374  0.1676  0.3717  0.3357   0.3556
# 2                    210  0.2839  0.2754  0.1256  0.1901  0.4537   0.3581
# 3                    215  0.3094  0.3275  0.1035  0.2566  0.3610   0.2906
# 4                    220  0.3611  0.3692  0.2987  0.2485  0.3712   0.3393
#
#    22 días  28 días  70 días  100 días  130 días
# 0   0.2768   0.3117   3.6349    3.6374    3.6374
# 1   0.2723   0.3381   3.7639    3.7454    3.7454
# 2   0.3098   0.3139   3.7607    3.7767    3.7767
# 3   0.3425   0.2984   3.7725    3.8094    3.8094
# 4   0.2495   0.4426   3.8962    3.9615    3.9615

# %%
wavelenght=datos.iloc[50:121,0]
absorbance_1=datos.iloc[50:121,1]
absorbance_2=datos.iloc[50:121,2]
absorbance_3=datos.iloc[50:121,3]
absorbance_4=datos.iloc[50:121,4]
absorbance_5=datos.iloc[50:121,5]
absorbance_6=datos.iloc[50:121,6]
absorbance_7=datos.iloc[50:121,7]
absorbance_8=datos.iloc[50:121,8]
absorbance_9=datos.iloc[50:121,9]
absorbance_10=datos.iloc[50:121,10]
absorbance_11=datos.iloc[50:121,11]

# %%
plt.style.use("seaborn-v0_8")
plt.plot(wavelenght,absorbance_1,label="5 min")
plt.plot(wavelenght,absorbance_2,label="12 min")
plt.plot(wavelenght,absorbance_3,label="35 min")
plt.plot(wavelenght,absorbance_4,label="2 días")
plt.plot(wavelenght,absorbance_6,label="14 días")
plt.plot(wavelenght,absorbance_7,label="22 días")
plt.plot(wavelenght,absorbance_8,label="28 días")
plt.plot(wavelenght,absorbance_9,label="70 días")
plt.plot(wavelenght,absorbance_10,label="100 días")
plt.plot(wavelenght,absorbance_11,label="130 días")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("absorbancia (a.u.)")
plt.legend(loc="best", frameon=False)
plt.show()
